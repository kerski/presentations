# %%
# Standard Library Imports
import uuid
import datetime

# Third-Party Imports
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
from pyspark.sql.functions import lit

# Local Imports
import sempy.fabric as fabric
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 41, Finished, Available, Finished)

# %%
# Retrieve DAX Queries

df = spark.sql(
    "SELECT Repository_ID, Object_ID, Path, Semantic_Model_Name, DAX_Query FROM DQV_Example.`DAX Query View Test Files` LIMIT 1000"
)

workspace_name = mssparkutils.env.getWorkspaceName()
df = df.withColumn("workspace_name", lit(workspace_name))

def clean_data(df):
    """
    Filter rows where 'Path' does NOT end with the given suffixes.
    """
    df = df.filter(
        ~df["Path"].rlike(r"\.RLS\.Test\.dax$|\.RLS\.Tests\.dax$")
    )
    return df

df_clean = clean_data(df)
display(df_clean)
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 42, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 582a9720-4206-4296-b2de-8a3c46eb9c4d)

# %%
# Retrieve DAX Queries

from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
from pyspark.sql.functions import lit
import uuid
import datetime
import sempy.fabric as fabric

df = spark.sql(
    "SELECT * FROM DQV_Example.`DAX Query View Test Files` LIMIT 1000"
)

workspace_name = mssparkutils.env.getWorkspaceName()
df = df.withColumn("workspace_name", lit(workspace_name))

def clean_data(df):
    """
    Filter rows where 'Path' does NOT end with the given suffixes.
    """
    df = df.filter(
        ~df["Path"].rlike(r"\.RLS\.Test\.dax$|\.RLS\.Tests\.dax$")
    )
    return df

df_clean = clean_data(df)
display(df_clean)

# Define schema explicitly
schema = StructType([
    StructField("Run_GUID", StringType(), True),
    StructField("Test_Name", StringType(), True),
    StructField("Expected_Value", StringType(), True),
    StructField("Actual_Value", StringType(), True),
    StructField("Passed", StringType(), True),
    StructField("Timestamp", TimestampType(), True),
    StructField("Semantic_Model", StringType(), True),
    StructField("Workspace_Name", StringType(), True),
])

# Function to process query and return results
def send_query(row):
    """
    Process DAX query results and return structured data.
    """
    dax_query = row["DAX_Query"]
    semantic_model = row["Semantic_Model_Name"]
    workspace_name = row["workspace_name"]

    # Generate Run GUID and Timestamp
    run_uuid = str(uuid.uuid4())
    run_dt = datetime.datetime.now()

    # Replace with actual function call
    dqs = fabric.evaluate_dax(semantic_model, dax_query, workspace_name)

    # Ensure dqs contains expected columns
    expected_cols = {"[TestName]", "[ExpectedValue]", "[ActualValue]", "[Passed]"}
    if not expected_cols.issubset(dqs.columns):
        raise ValueError(f"Missing expected columns in the DAX result. Found: {list(dqs.columns)}")

    # Extract and rename fields
    test_results = dqs[["[TestName]", "[ExpectedValue]", "[ActualValue]", "[Passed]"]].copy()
    test_results["Run_GUID"] = run_uuid
    test_results["Test_Name"] = test_results["[TestName]"]
    test_results["Expected_Value"] = test_results["[ExpectedValue]"].astype(str)
    test_results["Actual_Value"] = test_results["[ActualValue]"].astype(str)
    test_results["Passed"] = test_results["[Passed]"].astype(str)
    test_results["Timestamp"] = run_dt
    test_results["Semantic_Model"] = semantic_model
    test_results["Workspace_Name"] = workspace_name

    # Convert each row into a Row object for Spark RDD
    return [
        Row(
            Run_GUID=row["Run_GUID"],
            Test_Name=row["Test_Name"],
            Expected_Value=row["Expected_Value"],
            Actual_Value=row["Actual_Value"],
            Passed=row["Passed"],
            Timestamp=datetime.datetime.strptime(str(row["Timestamp"]), "%Y-%m-%d %H:%M:%S.%f"),
            Semantic_Model=row["Semantic_Model"],
            Workspace_Name=row["Workspace_Name"],
        )
        for _, row in test_results.iterrows()
    ]

# Convert DataFrame to RDD, process each row, and convert back with schema
df_rdd = df_clean.rdd.flatMap(send_query)
df_results = spark.createDataFrame(df_rdd, schema)

# Display results in Spark DataFrame
df_results.show(truncate=False)
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 43, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 02b1ddfd-8d33-4eb8-9253-5414e713cc4f)
# +------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------+------------------------------------+------+--------------------------+--------------+--------------+
# |Run_GUID                            |Test_Name                                                                                |Expected_Value                      |Actual_Value                        |Passed|Timestamp                 |Semantic_Model|Workspace_Name|
# +------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------+------------------------------------+------+--------------------------+--------------+--------------+
# |2b0d72ba-bee2-455a-9674-c96109253a91|Calculated Column: Month Year column should be blank when no date (1/1/0001) is selected.|Not Available                       |Not Available                       |True  |2025-04-02 06:59:35.983435|SampleModel   |fabcon-2025   |
# |2b0d72ba-bee2-455a-9674-c96109253a91|Calculated Column: Month Year column should be Jan-11 when filtered by January 1, 2011.  |Jan-11                              |Jan-11                              |True  |2025-04-02 06:59:35.983435|SampleModel   |fabcon-2025   |
# |2b0d72ba-bee2-455a-9674-c96109253a91|Calculated Column: Month Year column should be Jan-11 when filtered by January 1, 2011. 2|Jan-11                              |Jan-11                              |True  |2025-04-02 06:59:35.983435|SampleModel   |fabcon-2025   |
# |d2897e66-5521-490e-b990-4c139962db5d|Measure: Number of Characters Test for Good Alignment Should be 178                      |1178                                |1178                                |True  |2025-04-02 06:59:39.114751|SampleModel   |fabcon-2025   |
# |d2897e66-5521-490e-b990-4c139962db5d|Measure: Number of Characters Test for Bad Alignment Should be 209                       |1209                                |1209                                |True  |2025-04-02 06:59:39.114751|SampleModel   |fabcon-2025   |
# |ba002701-c01a-4f7e-8682-a586b8cad3af|Measure: Running Total of Appeareances should not be altered by Alignment Filter         |TRUE                                |TRUE                                |True  |2025-04-02 06:59:39.559837|SampleModel   |fabcon-2025   |
# |ba002701-c01a-4f7e-8682-a586b8cad3af|Measure: Top Rank in Appearances for Good Alignment should be Spider-man                 |1678                                |1678                                |True  |2025-04-02 06:59:39.559837|SampleModel   |fabcon-2025   |
# |ba002701-c01a-4f7e-8682-a586b8cad3af|Measure: Top Rank in Appearances for Neutral Alignment should be Wolverine               |64786                               |64786                               |True  |2025-04-02 06:59:39.559837|SampleModel   |fabcon-2025   |
# |ba002701-c01a-4f7e-8682-a586b8cad3af|Measure: Date Filter should output 'between January, 2010 and June, 2011'                |between January, 2010 and June, 2011|between January, 2010 and June, 2011|True  |2025-04-02 06:59:39.559837|SampleModel   |fabcon-2025   |
# |ba002701-c01a-4f7e-8682-a586b8cad3af|Measure: Single Date Filter should output 'for the month of June, 2011'                  |for the month of June, 2011         |for the month of June, 2011         |True  |2025-04-02 06:59:39.559837|SampleModel   |fabcon-2025   |
# |e727cf9e-2ccd-4ab5-a6f3-e8137aa6d9ba|Measure: Test 1                                                                          |1                                   |1                                   |True  |2025-04-02 06:59:40.127193|SampleModel   |fabcon-2025   |
# |e727cf9e-2ccd-4ab5-a6f3-e8137aa6d9ba|Measure: Test 2                                                                          |1                                   |1                                   |True  |2025-04-02 06:59:40.127193|SampleModel   |fabcon-2025   |
# |e727cf9e-2ccd-4ab5-a6f3-e8137aa6d9ba|Measure: Test 3                                                                          |1                                   |1                                   |True  |2025-04-02 06:59:40.127193|SampleModel   |fabcon-2025   |
# |a363f04a-e360-4aef-b537-ba246a73339a|Alignment Schema matches expectations                                                    |0                                   |2                                   |False |2025-04-02 06:59:40.643416|SampleModel   |fabcon-2025   |
# |a467b79c-065d-4d64-8dc4-944224c84c54|Alignment Schema matches expectations                                                    |0                                   |0                                   |True  |2025-04-02 06:59:41.108285|SampleModel   |fabcon-2025   |
# |a467b79c-065d-4d64-8dc4-944224c84c54|Marvel Fact EXACTLY matches expectations                                                 |0                                   |2                                   |False |2025-04-02 06:59:41.108285|SampleModel   |fabcon-2025   |
# |4a8c91d2-e793-4f27-b082-79c8d7a8547e|Marvel Fact: Date ID has no null values.                                                 |0                                   |0                                   |True  |2025-04-02 06:59:41.46396 |SampleModel   |fabcon-2025   |
# |4a8c91d2-e793-4f27-b082-79c8d7a8547e|Marvel Fact: ID has distinct values.                                                     |16376                               |16376                               |True  |2025-04-02 06:59:41.46396 |SampleModel   |fabcon-2025   |
# |4a8c91d2-e793-4f27-b082-79c8d7a8547e|Marvel Fact: Percentage of null values does not exceed 15%.                              |1                                   |1                                   |True  |2025-04-02 06:59:41.46396 |SampleModel   |fabcon-2025   |
# +------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------+------------------------------------+------+--------------------------+--------------+--------------+

# %% [markdown]
# ## RLS Example

# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 48, Finished, Available, Finished)
# Requirement already satisfied: semantic-link-labs in /nfs4/pyenv-86c1a7a1-3584-4dd9-a11c-df330c0cbd7a/lib/python3.11/site-packages (0.9.7)
# Requirement already satisfied: semantic-link-sempy>=0.9.3 in /nfs4/pyenv-86c1a7a1-3584-4dd9-a11c-df330c0cbd7a/lib/python3.11/site-packages (from semantic-link-labs) (0.10.1)
# Requirement already satisfied: anytree in /nfs4/pyenv-86c1a7a1-3584-4dd9-a11c-df330c0cbd7a/lib/python3.11/site-packages (from semantic-link-labs) (2.12.1)
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-labs) (3.1.1)
# Requirement already satisfied: polib in /nfs4/pyenv-86c1a7a1-3584-4dd9-a11c-df330c0cbd7a/lib/python3.11/site-packages (from semantic-link-labs) (1.2.0)
# Requirement already satisfied: jsonpath_ng in /nfs4/pyenv-86c1a7a1-3584-4dd9-a11c-df330c0cbd7a/lib/python3.11/site-packages (from semantic-link-labs) (1.7.0)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas>=2.0.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.9.3->semantic-link-labs) (8.20.0)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from anytree->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (8.1.2)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.0.0)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from powerbiclient->semantic-link-labs) (1.25.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.9.3->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.9.3->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.9.3)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.16.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.10)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.8.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (42.0.2)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=2.0.3->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=2.0.3->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=2.0.3->semantic-link-sempy>=0.9.3->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=2.0.3->semantic-link-sempy>=0.9.3->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.9.3->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.2.5)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.9.3->semantic-link-labs) (0.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
# Imports
import uuid
import datetime

# Third-Party Imports
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, StringType, TimestampType
from pyspark.sql.functions import lit

# Local Imports
import sempy_labs as labs
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 57, Finished, Available, Finished)

# %%
# Retrieve RLS DAX Query Data
rls_df = spark.sql(
    "SELECT  Repository_ID, User, Object_ID, Semantic_Model_Name, DAX_Query FROM DQV_Example.`RLS DAX Query View Test Files` LIMIT 1000"
)

workspace_name = mssparkutils.env.getWorkspaceName()
rls_df = rls_df.withColumn('workspace_name', lit(workspace_name))

# Display DataFrame
display(rls_df)
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 62, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 3e771fb4-ebd5-4b3f-9f0e-145636213ce7)

# %%
# Define schema explicitly
rls_schema = StructType([
    StructField('Run_GUID', StringType(), True),
    StructField('Test_Name', StringType(), True),
    StructField('User', StringType(), True),
    StructField('Expected_Value', StringType(), True),
    StructField('Actual_Value', StringType(), True),
    StructField('Passed', StringType(), True),
    StructField('Timestamp', TimestampType(), True),
    StructField('Semantic_Model', StringType(), True),
    StructField('Workspace_Name', StringType(), True)
])

# Function to process query and return results
def send_rls_query(row):
    dax_query = row["DAX_Query"]
    semantic_model = row["Semantic_Model_Name"]
    workspace_name = row["workspace_name"]
    impersonated_user = row["User"]

    # Generate Run GUID and Timestamp
    run_uuid = str(uuid.uuid4())
    run_dt = datetime.datetime.now()  # Ensure it's a Python datetime object

    # Replace with actual function call
    # dqs = fabric.evaluate_dax(semantic_model, dax_query, workspace_name)  # Ensure output is a DataFrame
    dqs = labs.evaluate_dax_impersonation(
        semantic_model, dax_query, impersonated_user, workspace_name
    )

    # Ensure dqs contains expected columns
    expected_cols = {'[TestName]', '[ExpectedValue]', '[ActualValue]', '[Passed]'}
    if not expected_cols.issubset(dqs.columns):
        raise ValueError(f"Missing expected columns in the DAX result. Found: {list(dqs.columns)}")

    # Extract and rename fields
    test_results = dqs[['[TestName]', '[ExpectedValue]', '[ActualValue]', '[Passed]']].copy()
    test_results['Run_GUID'] = run_uuid
    test_results['Test_Name'] = test_results['[TestName]']
    test_results['Expected_Value'] = test_results['[ExpectedValue]'].astype(str)
    test_results['Actual_Value'] = test_results['[ActualValue]'].astype(str)
    test_results['Passed'] = test_results['[Passed]'].astype(str)
    
    # Ensure Timestamp is correctly converted
    test_results['Timestamp'] = run_dt  # Keep as Python datetime object

    test_results['Semantic_Model'] = semantic_model
    test_results['Workspace_Name'] = workspace_name

    # Convert each row into a Row object for Spark RDD
    return [
        Row(
            Run_GUID=row['Run_GUID'],
            Test_Name=row['Test_Name'],
            User=impersonated_user,
            Expected_Value=row['Expected_Value'],
            Actual_Value=row['Actual_Value'],
            Passed=row['Passed'],
            Timestamp=datetime.datetime.strptime(str(row['Timestamp']), "%Y-%m-%d %H:%M:%S.%f"),  # Explicit conversion
            Semantic_Model=row['Semantic_Model'],
            Workspace_Name=row['Workspace_Name']
        ) 
        for _, row in test_results.iterrows()
    ]

# Convert DataFrame to RDD, process each row, and convert back with schema
rls_df_rdd = rls_df.rdd.flatMap(send_rls_query)  # flatMap handles list output from function
rls_df_results = spark.createDataFrame(rls_df_rdd, rls_schema)

# Display results in Spark DataFrame
rls_df_results.show(truncate=False)
# Out:
# StatementMeta(, 698799bc-0eff-4d5d-96da-4c27ebe6306e, 63, Finished, Available, Finished)
# +------------------------------------+--------------------------------------+---------------------+--------------+------------+------+--------------------------+--------------+--------------+
# |Run_GUID                            |Test_Name                             |User                 |Expected_Value|Actual_Value|Passed|Timestamp                 |Semantic_Model|Workspace_Name|
# +------------------------------------+--------------------------------------+---------------------+--------------+------------+------+--------------------------+--------------+--------------+
# |5222c852-f983-43b6-b14b-44b6f5093115|RLS Test: A should not see B          |DataOpsSvc@kerski.net|1             |1           |True  |2025-04-02 07:12:48.851446|RLSExample    |fabcon-2025   |
# |5222c852-f983-43b6-b14b-44b6f5093115|RLS Test: A should only see one record|DataOpsSvc@kerski.net|1             |1           |True  |2025-04-02 07:12:48.851446|RLSExample    |fabcon-2025   |
# +------------------------------------+--------------------------------------+---------------------+--------------+------------+------+--------------------------+--------------+--------------+
